# %% [markdown]
# ### hypothesis
# find life expectancy based of

# %%
import pandas as pd
data = pd.read_excel(r"E:\DebugShala\Machine learning\6 ML intro_superviesd_unsup_&_Regression\Life_Expectancy_Data.xls")
# Out:
# C:\Users\HIMANSHU SURYAVANSHI\anaconda3\Lib\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %%
data.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Life expectancy ', 'Adult Mortality',
#        'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
#        'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
#        'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
#        ' thinness  1-19 years', ' thinness 5-9 years',
#        'Income composition of resources', 'Schooling'],
#       dtype='object')

# %%
## reshuffling the columns
data1 = data.reindex(columns=['Country', 'Year', 'Status', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling','Life expectancy '])

# %%
data1.head()
# Out:
#        Country  Year      Status  Adult Mortality  infant deaths  Alcohol  \
# 0  Afghanistan  2015  Developing            263.0             62     0.01
# 1  Afghanistan  2014  Developing            271.0             64     0.01
# 2  Afghanistan  2013  Developing            268.0             66     0.01
# 3  Afghanistan  2012  Developing            272.0             69     0.01
# 4  Afghanistan  2011  Developing            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2938 entries, 0 to 2937
# Data columns (total 22 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Country                          2938 non-null   object
#  1   Year                             2938 non-null   int64
#  2   Status                           2938 non-null   object
#  3   Adult Mortality                  2928 non-null   float64
#  4   infant deaths                    2938 non-null   int64
#  5   Alcohol                          2744 non-null   float64
#  6   percentage expenditure           2938 non-null   float64
#  7   Hepatitis B                      2385 non-null   float64
#  8   Measles                          2938 non-null   int64
#  9    BMI                             2904 non-null   float64
#  10  under-five deaths                2938 non-null   int64
#  11  Polio                            2919 non-null   float64
# ...

# %%
data1.isna().sum()
# Out:
# Country                              0
# Year                                 0
# Status                               0
# Adult Mortality                     10
# infant deaths                        0
# Alcohol                            194
# percentage expenditure               0
# Hepatitis B                        553
# Measles                              0
#  BMI                                34
# under-five deaths                    0
# Polio                               19
# Total expenditure                  226
# Diphtheria                          19
#  HIV/AIDS                            0
# GDP                                448
# Population                         652
#  thinness  1-19 years               34
#  thinness 5-9 years                 34
# Income composition of resources    167
# Schooling                          163
# Life expectancy                     10
# dtype: int64

# %%
df = data1.dropna()

# %% [markdown]
# ## dealing with categorical data

# %%
df.columns
# Out:
# Index(['Country', 'Year', 'Status', 'Adult Mortality', 'infant deaths',
#        'Alcohol', 'percentage expenditure', 'Hepatitis B', 'Measles ', ' BMI ',
#        'under-five deaths ', 'Polio', 'Total expenditure', 'Diphtheria ',
#        ' HIV/AIDS', 'GDP', 'Population', ' thinness  1-19 years',
#        ' thinness 5-9 years', 'Income composition of resources', 'Schooling',
#        'Life expectancy '],
#       dtype='object')

# %%
cat_col = ['Country',"Status"]

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()

# %%
for i in cat_col:
    df[i] = lb.fit_transform(df[i])
df[i]
# Out:
# C:\Users\HIMANSHU SURYAVANSHI\AppData\Local\Temp\ipykernel_12784\1018762908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = lb.fit_transform(df[i])
# C:\Users\HIMANSHU SURYAVANSHI\AppData\Local\Temp\ipykernel_12784\1018762908.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = lb.fit_transform(df[i])
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#        ..
# 2933    1
# 2934    1
# 2935    1
# 2936    1
# 2937    1
# ...

# %%
df.head()
# Out:
#    Country  Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0        0  2015       1            263.0             62     0.01
# 1        0  2014       1            271.0             64     0.01
# 2        0  2013       1            268.0             66     0.01
# 3        0  2012       1            272.0             69     0.01
# 4        0  2011       1            275.0             71     0.01
#
#    percentage expenditure  Hepatitis B  Measles    BMI   ...  \
# 0               71.279624         65.0      1154   19.1  ...
# 1               73.523582         62.0       492   18.6  ...
# 2               73.219243         64.0       430   18.1  ...
# 3               78.184215         67.0      2787   17.6  ...
# 4                7.097109         68.0      3013   17.2  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS         GDP  Population  \
# 0               8.16         65.0        0.1  584.259210  33736494.0
# ...

# %% [markdown]
# ## dealing with cont_columns

# %%
from sklearn.preprocessing import MinMaxScaler
mm = MinMaxScaler()

# %%
con_col = ['Year', 'Adult Mortality',
       'infant deaths', 'Alcohol', 'percentage expenditure', 'Hepatitis B',
       'Measles ', ' BMI ', 'under-five deaths ', 'Polio', 'Total expenditure',
       'Diphtheria ', ' HIV/AIDS', 'GDP', 'Population',
       ' thinness  1-19 years', ' thinness 5-9 years',
       'Income composition of resources', 'Schooling']

# %%
for i in con_col:
    df[i] = mm.fit_transform(df[i].values.reshape(-1,1))
df[i].head()
# Out:
# C:\Users\HIMANSHU SURYAVANSHI\AppData\Local\Temp\ipykernel_12784\285798359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = mm.fit_transform(df[i].values.reshape(-1,1))
# C:\Users\HIMANSHU SURYAVANSHI\AppData\Local\Temp\ipykernel_12784\285798359.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[i] = mm.fit_transform(df[i].values.reshape(-1,1))
# C:\Users\HIMANSHU SURYAVANSHI\AppData\Local\Temp\ipykernel_12784\285798359.py:2: SettingWithCopyWarning:
# ...

# %%
df.head()
# Out:
#    Country      Year  Status  Adult Mortality  infant deaths  Alcohol  \
# 0        0  1.000000       1         0.362881       0.038750      0.0
# 1        0  0.933333       1         0.373961       0.040000      0.0
# 2        0  0.866667       1         0.369806       0.041250      0.0
# 3        0  0.800000       1         0.375346       0.043125      0.0
# 4        0  0.733333       1         0.379501       0.044375      0.0
#
#    percentage expenditure  Hepatitis B  Measles       BMI   ...  \
# 0                0.003759     0.649485  0.008780  0.227696  ...
# 1                0.003878     0.618557  0.003743  0.221039  ...
# 2                0.003861     0.639175  0.003271  0.214381  ...
# 3                0.004123     0.670103  0.021203  0.207723  ...
# 4                0.000374     0.680412  0.022923  0.202397  ...
#
#    Total expenditure  Diphtheria    HIV/AIDS       GDP  Population  \
# 0           0.543590     0.649485        0.0  0.004889    0.026074
# ...

# %%
### splitting into train test
from sklearn.model_selection import train_test_split
train, test = train_test_split(df,test_size=0.2)

# %%
df.shape
# Out:
# (1649, 22)

# %%
train.shape
# Out:
# (1319, 22)

# %%
test.shape
# Out:
# (330, 22)

# %%
### separating independent and dependent variables

train_x = train.iloc[:,:-1] # independent
train_y = train.iloc[:,-1] # dependent

# %%
test_x = test.iloc[:,:-1] # independent
test_y = test.iloc[:,-1] # dependent

# %%
## simple linear regression

from sklearn.linear_model import LinearRegression
mlr = LinearRegression().fit(train_x,train_y)

# %%
prd = mlr.predict(test_x)
prd
# Out:
# array([75.39364065, 70.05057063, 70.3823189 , 81.52972578, 74.04699975,
#        68.69788659, 63.22521535, 67.36005063, 83.17060587, 62.3859129 ,
#        43.01642994, 67.83841039, 77.41806269, 58.50527705, 74.1267769 ,
#        69.93459379, 69.16826867, 71.01389686, 71.34217026, 73.65679919,
#        79.91399276, 66.5324312 , 72.87970758, 69.32229919, 84.87588067,
#        71.12155682, 69.77210028, 72.46768038, 50.84561936, 60.48560802,
#        83.34578567, 60.26551889, 76.37225796, 74.49375066, 66.48969408,
#        60.76492776, 69.81218524, 65.46796678, 60.4828303 , 68.36740263,
#        70.79102436, 36.84538058, 86.15361227, 72.12029645, 71.05909785,
#        72.90228821, 82.25520199, 74.95509741, 76.7632081 , 71.71890959,
#        75.54032802, 63.24094791, 78.38604953, 72.09379479, 71.95018631,
#        71.46648121, 67.69521026, 84.21536983, 76.36977817, 82.59743016,
#        71.35063637, 72.43021875, 70.7419578 , 77.09809695, 79.50031019,
# ...

# %%
test_y
# Out:
# 1531    76.0
# 454     72.4
# 779     72.3
# 1004    79.2
# 358     73.6
#         ...
# 452     72.6
# 761     59.8
# 2621    58.3
# 1739    74.6
# 890     58.5
# Name: Life expectancy , Length: 330, dtype: float64

# %%
# rmse

import numpy as np

rmse = np.sqrt(np.mean(prd-test_y)**2)

# %%
rmse
# Out:
# 0.09048209537236093
